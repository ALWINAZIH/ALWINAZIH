# %% [markdown]
# <a href="https://colab.research.google.com/github/ALWINAZIH/ALWINAZIH/blob/main/YOLOV10DISEASDETECTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Installing the ultralytics package. (installing the latest package in our case the latest is YOLOv8)
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 19.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 123.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 96.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 42.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 104.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
#Installing roboflow
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 49.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 117.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 114.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="plhcLBf54yAQCtZK15IK")
project = rf.workspace("nazihs-workspace").project("fish-skin-diseases-detection-wyru9")
version = project.version(1)
dataset = version.download("yolov9")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to fish-skin-diseases-detection-1 in yolov9:: 100%|██████████| 1860/1860 [00:00<00:00, 3365.13it/s]

# %%
# !pip install ultralytics
# %cd {HOME}

# !yolo task=detect mode=train model=yolo9s.pt data={dataset.location}/data.yaml epochs=170 imgsz=640 plots=True
# Out:
# ...
# [Errno 2] No such file or directory: '{HOME}'
# /content
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/cfg/__init__.py", line 956, in entrypoint
#     model = YOLO(model, task=task)
#             ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/models/yolo/model.py", line 79, in __init__
#     super().__init__(model=model, task=task, verbose=verbose)
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py", line 151, in __init__
#     self._load(model, task=task)
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py", line 295, in _load
#     self.model, self.ckpt = attempt_load_one_weight(weights)
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# Download YOLOv10s model
# !wget https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10s.pt
# Out:
# --2025-07-08 06:55:13--  https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10s.pt
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/THU-MIG/yolov10/releases/download/v1.0/yolov10s.pt [following]
# --2025-07-08 06:55:13--  https://github.com/THU-MIG/yolov10/releases/download/v1.0/yolov10s.pt
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="plhcLBf54yAQCtZK15IK")
project = rf.workspace("nazihs-workspace").project("fish-skin-diseases-detection-wyru9")
version = project.version(1)
dataset = version.download("yolov9")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolo110s.pt data={dataset.location}/data.yaml epochs=170 imgsz=640 plots=True
# Out:
# [Errno 2] No such file or directory: '{HOME}'
# /content
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/cfg/__init__.py", line 956, in entrypoint
#     model = YOLO(model, task=task)
#             ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/models/yolo/model.py", line 79, in __init__
#     super().__init__(model=model, task=task, verbose=verbose)
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py", line 151, in __init__
#     self._load(model, task=task)
#   File "/usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py", line 295, in _load
#     self.model, self.ckpt = attempt_load_one_weight(weights)
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# Train the YOLOv10s model
# !yolo task=detect mode=train model=yolov10s.pt data={dataset.location}/data.yaml epochs=170 imgsz=640 plots=True
# Out:
# Ultralytics 8.3.162 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
# 1. Monter Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 2. Créer un dossier pour les sauvegardes
# !mkdir -p /content/drive/MyDrive/YOLO_Backups

# 3. Copier le fichier du modèle entraîné (.pt) vers Google Drive
# !cp /content/runs/detect/train/weights/best.pt /content/drive/MyDrive/YOLO_Backups/

# 4. (Optionnel) Copier tout le dossier des résultats de l'entraînement
# !cp -r /content/runs/detect/train /content/drive/MyDrive/YOLO_Backups/train_results
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-12-1280757649.py in <cell line: 0>()
#       1 # 1. Monter Google Drive
#       2 from google.colab import drive
# ----> 3 drive.mount('/content/drive')
#       4
#       5 # 2. Créer un dossier pour les sauvegardes
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
# ...

# %%
from IPython.display import Image

Image(filename=f'/content/runs/detect/train/val_batch2_labels.jpg', width=600)

# %%
# 1. Monter Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 2. Créer un dossier pour les sauvegardes
# !mkdir -p /content/drive/MyDrive/YOLO_Backups

# 3. Copier le fichier du modèle entraîné (.pt) vers Google Drive
# !cp /content/runs/detect/train/weights/best.pt /content/drive/MyDrive/YOLO_Backups/

# 4. (Optionnel) Copier tout le dossier des résultats de l'entraînement
# !cp -r /content/runs/detect/train /content/drive/MyDrive/YOLO_Backups/train_results
# Out:
# Mounted at /content/drive

# %%
from IPython.display import Image

Image(filename=f'/content/runs/detect/train/results.png', width=600)
